# %%
! pip install requests
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/matches/v1/recent"

headers = {
	"x-rapidapi-key": "df0bd482a6mshb51dd03e9130c35p1ba9a3jsn359a8c907fc1",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'typeMatches': [{'matchType': 'International', 'seriesMatches': [{'seriesAdWrapper': {'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matches': [{'matchInfo': {'matchId': 116954, 'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matchDesc': '3rd T20I', 'matchFormat': 'T20', 'startDate': '1762071300000', 'endDate': '1762083900000', 'state': 'Complete', 'status': 'India won by 5 wkts', 'team1': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 776202}, 'team2': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 776162}, 'venueInfo': {'id': 39, 'ground': 'Bellerive Oval', 'city': 'Hobart', 'timezone': '+11:00', 'latitude': '-42.877296', 'longitude': '147.374013'}, 'currBatTeamId': 2, 'seriesStartDt': '1760832000000', 'seriesEndDt': '1762732800000', 'isTimeAnnounced': True, 'stateTitle': 'IND Won'}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 186, 'wickets': 6, 'overs': 19.6}}, 'team2Score': {'inng
# ...

# %%
data=(response.json())
print(data)
# Out:
# {'typeMatches': [{'matchType': 'International', 'seriesMatches': [{'seriesAdWrapper': {'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matches': [{'matchInfo': {'matchId': 116954, 'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matchDesc': '3rd T20I', 'matchFormat': 'T20', 'startDate': '1762071300000', 'endDate': '1762083900000', 'state': 'Complete', 'status': 'India won by 5 wkts', 'team1': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 776202}, 'team2': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 776162}, 'venueInfo': {'id': 39, 'ground': 'Bellerive Oval', 'city': 'Hobart', 'timezone': '+11:00', 'latitude': '-42.877296', 'longitude': '147.374013'}, 'currBatTeamId': 2, 'seriesStartDt': '1760832000000', 'seriesEndDt': '1762732800000', 'isTimeAnnounced': True, 'stateTitle': 'IND Won'}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 186, 'wickets': 6, 'overs': 19.6}}, 'team2Score': {'inng
# ...

# %%
data.keys()
# Out:
# dict_keys(['typeMatches', 'filters', 'appIndex', 'responseLastUpdated'])

# %%
type_match=data['typeMatches']
print(type_match)
# Out:
# [{'matchType': 'International', 'seriesMatches': [{'seriesAdWrapper': {'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matches': [{'matchInfo': {'matchId': 116954, 'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matchDesc': '3rd T20I', 'matchFormat': 'T20', 'startDate': '1762071300000', 'endDate': '1762083900000', 'state': 'Complete', 'status': 'India won by 5 wkts', 'team1': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 776202}, 'team2': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 776162}, 'venueInfo': {'id': 39, 'ground': 'Bellerive Oval', 'city': 'Hobart', 'timezone': '+11:00', 'latitude': '-42.877296', 'longitude': '147.374013'}, 'currBatTeamId': 2, 'seriesStartDt': '1760832000000', 'seriesEndDt': '1762732800000', 'isTimeAnnounced': True, 'stateTitle': 'IND Won'}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 186, 'wickets': 6, 'overs': 19.6}}, 'team2Score': {'inngs1': {'inningsId
# ...

# %%
type_match[0].keys()
# Out:
# dict_keys(['matchType', 'seriesMatches'])

# %%
type_match[1]['seriesMatches']
# Out:
# [{'seriesAdWrapper': {'seriesId': 11110,
#    'seriesName': 'CSA T20 Knock Out Competition 2025',
#    'matches': [{'matchInfo': {'matchId': 136104,
#       'seriesId': 11110,
#       'seriesName': 'CSA T20 Knock Out Competition 2025',
#       'matchDesc': '9th Match',
#       'matchFormat': 'T20',
#       'startDate': '1762081200000',
#       'endDate': '1762093800000',
#       'state': 'Complete',
#       'status': 'Garden Route Badgers won by 24 runs',
#       'team1': {'teamId': 918,
#        'teamName': 'Garden Route Badgers',
#        'teamSName': 'GRB',
#        'imageId': 247396},
#       'team2': {'teamId': 923,
#        'teamName': 'Northern Cape',
#        'teamSName': 'NCAPE',
#        'imageId': 248438},
#       'venueInfo': {'id': 148,
#        'ground': 'Diamond Oval',
#        'city': 'Kimberley',
#        'timezone': '+02:00',
#        'latitude': '-28.742487',
#        'longitude': '24.742101'},
#       'currBatTeamId': 918,
# ...

# %%
Series_match=type_match[1]['seriesMatches']
print(Series_match)
# Out:
# [{'seriesAdWrapper': {'seriesId': 11110, 'seriesName': 'CSA T20 Knock Out Competition 2025', 'matches': [{'matchInfo': {'matchId': 136104, 'seriesId': 11110, 'seriesName': 'CSA T20 Knock Out Competition 2025', 'matchDesc': '9th Match', 'matchFormat': 'T20', 'startDate': '1762081200000', 'endDate': '1762093800000', 'state': 'Complete', 'status': 'Garden Route Badgers won by 24 runs', 'team1': {'teamId': 918, 'teamName': 'Garden Route Badgers', 'teamSName': 'GRB', 'imageId': 247396}, 'team2': {'teamId': 923, 'teamName': 'Northern Cape', 'teamSName': 'NCAPE', 'imageId': 248438}, 'venueInfo': {'id': 148, 'ground': 'Diamond Oval', 'city': 'Kimberley', 'timezone': '+02:00', 'latitude': '-28.742487', 'longitude': '24.742101'}, 'currBatTeamId': 918, 'seriesStartDt': '1761264000000', 'seriesEndDt': '1764028800000', 'isTimeAnnounced': True, 'stateTitle': 'Complete'}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 164, 'wickets': 4, 'overs': 19.6}}, 'team2Score': {'inngs1': {'
# ...

# %%
series_match=type_match[1]['seriesMatches']
print(series_match)
# Out:
# [{'seriesAdWrapper': {'seriesId': 11110, 'seriesName': 'CSA T20 Knock Out Competition 2025', 'matches': [{'matchInfo': {'matchId': 136104, 'seriesId': 11110, 'seriesName': 'CSA T20 Knock Out Competition 2025', 'matchDesc': '9th Match', 'matchFormat': 'T20', 'startDate': '1762081200000', 'endDate': '1762093800000', 'state': 'Complete', 'status': 'Garden Route Badgers won by 24 runs', 'team1': {'teamId': 918, 'teamName': 'Garden Route Badgers', 'teamSName': 'GRB', 'imageId': 247396}, 'team2': {'teamId': 923, 'teamName': 'Northern Cape', 'teamSName': 'NCAPE', 'imageId': 248438}, 'venueInfo': {'id': 148, 'ground': 'Diamond Oval', 'city': 'Kimberley', 'timezone': '+02:00', 'latitude': '-28.742487', 'longitude': '24.742101'}, 'currBatTeamId': 918, 'seriesStartDt': '1761264000000', 'seriesEndDt': '1764028800000', 'isTimeAnnounced': True, 'stateTitle': 'Complete'}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 164, 'wickets': 4, 'overs': 19.6}}, 'team2Score': {'inngs1': {'
# ...

# %%
series=series_match[0]['seriesAdWrapper']
print(series.keys())
# Out:
# dict_keys(['seriesId', 'seriesName', 'matches'])

# %%
series_key=list(series)
print(series_key)
# Out:
# ['seriesId', 'seriesName', 'matches']

# %%
series1=series['matches'] 
print(series)
# Out:
# {'seriesId': 11110, 'seriesName': 'CSA T20 Knock Out Competition 2025', 'matches': [{'matchInfo': {'matchId': 136104, 'seriesId': 11110, 'seriesName': 'CSA T20 Knock Out Competition 2025', 'matchDesc': '9th Match', 'matchFormat': 'T20', 'startDate': '1762081200000', 'endDate': '1762093800000', 'state': 'Complete', 'status': 'Garden Route Badgers won by 24 runs', 'team1': {'teamId': 918, 'teamName': 'Garden Route Badgers', 'teamSName': 'GRB', 'imageId': 247396}, 'team2': {'teamId': 923, 'teamName': 'Northern Cape', 'teamSName': 'NCAPE', 'imageId': 248438}, 'venueInfo': {'id': 148, 'ground': 'Diamond Oval', 'city': 'Kimberley', 'timezone': '+02:00', 'latitude': '-28.742487', 'longitude': '24.742101'}, 'currBatTeamId': 918, 'seriesStartDt': '1761264000000', 'seriesEndDt': '1764028800000', 'isTimeAnnounced': True, 'stateTitle': 'Complete'}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 164, 'wickets': 4, 'overs': 19.6}}, 'team2Score': {'inngs1': {'inningsId': 2, 'runs'
# ...

# %%
series1=series['matches']
print(series1)
# Out:
# [{'matchInfo': {'matchId': 136104, 'seriesId': 11110, 'seriesName': 'CSA T20 Knock Out Competition 2025', 'matchDesc': '9th Match', 'matchFormat': 'T20', 'startDate': '1762081200000', 'endDate': '1762093800000', 'state': 'Complete', 'status': 'Garden Route Badgers won by 24 runs', 'team1': {'teamId': 918, 'teamName': 'Garden Route Badgers', 'teamSName': 'GRB', 'imageId': 247396}, 'team2': {'teamId': 923, 'teamName': 'Northern Cape', 'teamSName': 'NCAPE', 'imageId': 248438}, 'venueInfo': {'id': 148, 'ground': 'Diamond Oval', 'city': 'Kimberley', 'timezone': '+02:00', 'latitude': '-28.742487', 'longitude': '24.742101'}, 'currBatTeamId': 918, 'seriesStartDt': '1761264000000', 'seriesEndDt': '1764028800000', 'isTimeAnnounced': True, 'stateTitle': 'Complete'}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 164, 'wickets': 4, 'overs': 19.6}}, 'team2Score': {'inngs1': {'inningsId': 2, 'runs': 140, 'wickets': 10, 'overs': 18.3}}}}, {'matchInfo': {'matchId': 136093, 'seriesI
# ...

# %%
series2=series.keys()
print(series2)
# Out:
# dict_keys(['seriesId', 'seriesName', 'matches'])

# %%
series3=series['matches']
first_match=series3[0]
print(first_match['matchInfo'])
# Out:
# {'matchId': 136104, 'seriesId': 11110, 'seriesName': 'CSA T20 Knock Out Competition 2025', 'matchDesc': '9th Match', 'matchFormat': 'T20', 'startDate': '1762081200000', 'endDate': '1762093800000', 'state': 'Complete', 'status': 'Garden Route Badgers won by 24 runs', 'team1': {'teamId': 918, 'teamName': 'Garden Route Badgers', 'teamSName': 'GRB', 'imageId': 247396}, 'team2': {'teamId': 923, 'teamName': 'Northern Cape', 'teamSName': 'NCAPE', 'imageId': 248438}, 'venueInfo': {'id': 148, 'ground': 'Diamond Oval', 'city': 'Kimberley', 'timezone': '+02:00', 'latitude': '-28.742487', 'longitude': '24.742101'}, 'currBatTeamId': 918, 'seriesStartDt': '1761264000000', 'seriesEndDt': '1764028800000', 'isTimeAnnounced': True, 'stateTitle': 'Complete'}

# %%
match_info=first_match['matchInfo']
print("matchId",match_info['matchId'])
print("seriesId",match_info['seriesId'])
print("seriesName",match_info['seriesName'])
print("matchDesc",match_info['matchDesc'])
print("matchFormat",match_info['matchFormat'])
print("startDate",match_info['startDate'])
print("endDate",match_info['endDate'])
print("state",match_info['state'])
print("status",match_info['status'])

print("team1",match_info['team1']['teamSName'])
print("team2",match_info['team2']['teamSName'])

print("venueInfo",match_info['venueInfo']['ground'])
# Out:
# matchId 136104
# seriesId 11110
# seriesName CSA T20 Knock Out Competition 2025
# matchDesc 9th Match
# matchFormat T20
# startDate 1762081200000
# endDate 1762093800000
# state Complete
# status Garden Route Badgers won by 24 runs
# team1 GRB
# team2 NCAPE
# venueInfo Diamond Oval

# %%
matches = []

for type_match in data.get("typeMatches", []):
    for series_match in type_match.get("seriesMatches", []):
        series = series_match.get("seriesAdWrapper", {})

        series_id = series.get("seriesId")
        series_name = series.get("seriesName")

        for match_obj in series.get("matches", []):
            match_info = match_obj.get("matchInfo", {})

            match_id = match_info.get("matchId")
            match_desc = match_info.get("matchDesc")
            match_format = match_info.get("matchFormat")
            start_date = match_info.get("startDate")
            end_date = match_info.get("endDate")
            state = match_info.get("state")
            status = match_info.get("status")
            team1 = match_info.get("team1", {}).get("teamSName")
            team2 = match_info.get("team2", {}).get("teamSName")
            venue_info = match_info.get("venueInfo", {}).get("ground")

            matches.append({
                "series_Id": series_id,
                "series_Name": series_name,
                "match_Desc": match_desc,
                "match_Format": match_format,
                "start_Date": start_date,
                "end_Date": end_date,
                "state": state,
                "status": status,
                "team1": team1,
                "team2": team2,
                "venue_Info": venue_info
            })

print(matches)
# Out:
# [{'series_Id': 9596, 'series_Name': 'India tour of Australia, 2025', 'match_Desc': '3rd T20I', 'match_Format': 'T20', 'start_Date': '1762071300000', 'end_Date': '1762083900000', 'state': 'Complete', 'status': 'India won by 5 wkts', 'team1': 'AUS', 'team2': 'IND', 'venue_Info': 'Bellerive Oval'}, {'series_Id': 9596, 'series_Name': 'India tour of Australia, 2025', 'match_Desc': '2nd T20I ', 'match_Format': 'T20', 'start_Date': '1761898500000', 'end_Date': '1761911100000', 'state': 'Complete', 'status': 'Australia won by 4 wkts', 'team1': 'IND', 'team2': 'AUS', 'venue_Info': 'Melbourne Cricket Ground'}, {'series_Id': 9596, 'series_Name': 'India tour of Australia, 2025', 'match_Desc': '1st T20I', 'match_Format': 'T20', 'start_Date': '1761725700000', 'end_Date': '1761738300000', 'state': 'Complete', 'status': 'No result (due to rain)', 'team1': 'IND', 'team2': 'AUS', 'venue_Info': 'Manuka Oval'}, {'series_Id': 10895, 'series_Name': 'South Africa tour of Pakistan, 2025', 'match_Desc': '3rd
# ...

# %%
PLAYERS details

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/player/trending"

headers = {
	"x-rapidapi-key": "df0bd482a6mshb51dd03e9130c35p1ba9a3jsn359a8c907fc1",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'player': [{'id': '28404', 'name': 'Roman Mazumder', 'teamName': 'Cyprus', 'faceImageId': 182026}, {'id': '13213', 'name': 'Rahmanullah Gurbaz', 'teamName': 'Afghanistan', 'faceImageId': 616556}, {'id': '1424820', 'name': 'Waqar Ali', 'teamName': 'Cyprus', 'faceImageId': 182026}, {'id': '1426296', 'name': 'Milen Gogev', 'teamName': 'Bulgaria', 'faceImageId': 182026}, {'id': '13217', 'name': 'Arshdeep Singh', 'teamName': 'India', 'faceImageId': 616527}, {'id': '8359', 'name': 'Babar Azam', 'teamName': 'Pakistan', 'faceImageId': 616440}, {'id': '8426', 'name': 'Harmeet Singh', 'teamName': 'United States of America', 'faceImageId': 156177}, {'id': '46772', 'name': 'Zeerak Chughtai', 'teamName': 'Bulgaria', 'faceImageId': 182026}, {'id': '10730', 'name': 'Blair Tickner', 'teamName': 'New Zealand', 'faceImageId': 226325}, {'id': '1427394', 'name': 'Taranjit Singh', 'teamName': 'Cyprus', 'faceImageId': 182026}], 'category': 'TRENDING SEARCHES'}

# %%
data=(response.json())
print(data)
# Out:
# {'player': [{'id': '28404', 'name': 'Roman Mazumder', 'teamName': 'Cyprus', 'faceImageId': 182026}, {'id': '13213', 'name': 'Rahmanullah Gurbaz', 'teamName': 'Afghanistan', 'faceImageId': 616556}, {'id': '1424820', 'name': 'Waqar Ali', 'teamName': 'Cyprus', 'faceImageId': 182026}, {'id': '1426296', 'name': 'Milen Gogev', 'teamName': 'Bulgaria', 'faceImageId': 182026}, {'id': '13217', 'name': 'Arshdeep Singh', 'teamName': 'India', 'faceImageId': 616527}, {'id': '8359', 'name': 'Babar Azam', 'teamName': 'Pakistan', 'faceImageId': 616440}, {'id': '8426', 'name': 'Harmeet Singh', 'teamName': 'United States of America', 'faceImageId': 156177}, {'id': '46772', 'name': 'Zeerak Chughtai', 'teamName': 'Bulgaria', 'faceImageId': 182026}, {'id': '10730', 'name': 'Blair Tickner', 'teamName': 'New Zealand', 'faceImageId': 226325}, {'id': '1427394', 'name': 'Taranjit Singh', 'teamName': 'Cyprus', 'faceImageId': 182026}], 'category': 'TRENDING SEARCHES'}

# %%
data1=data.keys()
print(data1)
# Out:
# dict_keys(['player', 'category'])

# %%
data2=data['player']
print(data2)
# Out:
# [{'id': '28404', 'name': 'Roman Mazumder', 'teamName': 'Cyprus', 'faceImageId': 182026}, {'id': '13213', 'name': 'Rahmanullah Gurbaz', 'teamName': 'Afghanistan', 'faceImageId': 616556}, {'id': '1424820', 'name': 'Waqar Ali', 'teamName': 'Cyprus', 'faceImageId': 182026}, {'id': '1426296', 'name': 'Milen Gogev', 'teamName': 'Bulgaria', 'faceImageId': 182026}, {'id': '13217', 'name': 'Arshdeep Singh', 'teamName': 'India', 'faceImageId': 616527}, {'id': '8359', 'name': 'Babar Azam', 'teamName': 'Pakistan', 'faceImageId': 616440}, {'id': '8426', 'name': 'Harmeet Singh', 'teamName': 'United States of America', 'faceImageId': 156177}, {'id': '46772', 'name': 'Zeerak Chughtai', 'teamName': 'Bulgaria', 'faceImageId': 182026}, {'id': '10730', 'name': 'Blair Tickner', 'teamName': 'New Zealand', 'faceImageId': 226325}, {'id': '1427394', 'name': 'Taranjit Singh', 'teamName': 'Cyprus', 'faceImageId': 182026}]

# %%
data3=data2[0]
print(data3.keys())
# Out:
# dict_keys(['id', 'name', 'teamName', 'faceImageId'])

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/player/8733/career"

headers = {
	"x-rapidapi-key": "df0bd482a6mshb51dd03e9130c35p1ba9a3jsn359a8c907fc1",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'values': [{'name': 't20', 'debut': 'vs Zimbabwe,  2016-06-18, Harare Sports Club', 'lastPlayed': 'vs England,  2022-11-10, Adelaide Oval', 'debutMatchID': '16610', 'lastPlayedMatchId': '43201'}, {'name': 'test', 'debut': 'vs Australia,  2014-12-26, Melbourne Cricket Ground', 'lastPlayed': 'vs West Indies,  2025-10-10, Arun Jaitley Stadium', 'debutMatchID': '13842', 'lastPlayedMatchId': '117362'}, {'name': 'odi', 'debut': 'vs Zimbabwe,  2016-06-11, Harare Sports Club', 'lastPlayed': 'vs Australia,  2025-10-25, Sydney Cricket Ground', 'debutMatchID': '16607', 'lastPlayedMatchId': '116927'}, {'name': 'ipl', 'debut': 'vs Kolkata Knight Riders,  2013-04-11, M.Chinnaswamy Stadium', 'lastPlayed': 'vs Punjab Kings,  2025-05-24, Sawai Mansingh Stadium', 'debutMatchID': '11876', 'lastPlayedMatchId': '118874'}, {'name': 'cl', 'debut': 'Not played', 'lastPlayed': 'Not played'}], 'appIndex': {'seoTitle': 'KL Rahul Profile - Cricbuzz | Cricbuzz.com', 'webURL': 'http://www.cricbuzz.com/profiles/8
# ...

# %%
data=(response.json())
print(data)
# Out:
# {'values': [{'name': 't20', 'debut': 'vs Zimbabwe,  2016-06-18, Harare Sports Club', 'lastPlayed': 'vs England,  2022-11-10, Adelaide Oval', 'debutMatchID': '16610', 'lastPlayedMatchId': '43201'}, {'name': 'test', 'debut': 'vs Australia,  2014-12-26, Melbourne Cricket Ground', 'lastPlayed': 'vs West Indies,  2025-10-10, Arun Jaitley Stadium', 'debutMatchID': '13842', 'lastPlayedMatchId': '117362'}, {'name': 'odi', 'debut': 'vs Zimbabwe,  2016-06-11, Harare Sports Club', 'lastPlayed': 'vs Australia,  2025-10-25, Sydney Cricket Ground', 'debutMatchID': '16607', 'lastPlayedMatchId': '116927'}, {'name': 'ipl', 'debut': 'vs Kolkata Knight Riders,  2013-04-11, M.Chinnaswamy Stadium', 'lastPlayed': 'vs Punjab Kings,  2025-05-24, Sawai Mansingh Stadium', 'debutMatchID': '11876', 'lastPlayedMatchId': '118874'}, {'name': 'cl', 'debut': 'Not played', 'lastPlayed': 'Not played'}], 'appIndex': {'seoTitle': 'KL Rahul Profile - Cricbuzz | Cricbuzz.com', 'webURL': 'http://www.cricbuzz.com/profiles/8
# ...

# %%
data1=data.keys()
print(data1)
# Out:
# dict_keys(['values', 'appIndex'])

# %%
data1=data['values']
print(data1)
# Out:
# [{'name': 't20', 'debut': 'vs Zimbabwe,  2016-06-18, Harare Sports Club', 'lastPlayed': 'vs England,  2022-11-10, Adelaide Oval', 'debutMatchID': '16610', 'lastPlayedMatchId': '43201'}, {'name': 'test', 'debut': 'vs Australia,  2014-12-26, Melbourne Cricket Ground', 'lastPlayed': 'vs West Indies,  2025-10-10, Arun Jaitley Stadium', 'debutMatchID': '13842', 'lastPlayedMatchId': '117362'}, {'name': 'odi', 'debut': 'vs Zimbabwe,  2016-06-11, Harare Sports Club', 'lastPlayed': 'vs Australia,  2025-10-25, Sydney Cricket Ground', 'debutMatchID': '16607', 'lastPlayedMatchId': '116927'}, {'name': 'ipl', 'debut': 'vs Kolkata Knight Riders,  2013-04-11, M.Chinnaswamy Stadium', 'lastPlayed': 'vs Punjab Kings,  2025-05-24, Sawai Mansingh Stadium', 'debutMatchID': '11876', 'lastPlayedMatchId': '118874'}, {'name': 'cl', 'debut': 'Not played', 'lastPlayed': 'Not played'}]

# %%
data1 = data['values']

result = { item['name']: item for item in data1 }

print(result)
# Out:
# {'t20': {'name': 't20', 'debut': 'vs Zimbabwe,  2016-06-18, Harare Sports Club', 'lastPlayed': 'vs England,  2022-11-10, Adelaide Oval', 'debutMatchID': '16610', 'lastPlayedMatchId': '43201'}, 'test': {'name': 'test', 'debut': 'vs Australia,  2014-12-26, Melbourne Cricket Ground', 'lastPlayed': 'vs West Indies,  2025-10-10, Arun Jaitley Stadium', 'debutMatchID': '13842', 'lastPlayedMatchId': '117362'}, 'odi': {'name': 'odi', 'debut': 'vs Zimbabwe,  2016-06-11, Harare Sports Club', 'lastPlayed': 'vs Australia,  2025-10-25, Sydney Cricket Ground', 'debutMatchID': '16607', 'lastPlayedMatchId': '116927'}, 'ipl': {'name': 'ipl', 'debut': 'vs Kolkata Knight Riders,  2013-04-11, M.Chinnaswamy Stadium', 'lastPlayed': 'vs Punjab Kings,  2025-05-24, Sawai Mansingh Stadium', 'debutMatchID': '11876', 'lastPlayedMatchId': '118874'}, 'cl': {'name': 'cl', 'debut': 'Not played', 'lastPlayed': 'Not played'}}

# %%
career=first_score
print("name",career)
# Out:
# name {'inningsid': 1, 'batsman': [{'id': 1114, 'balls': 5, 'runs': 5, 'fours': 1, 'sixes': 0, 'strkrate': '100', 'name': 'Stirling', 'nickname': '', 'iscaptain': False, 'iskeeper': False, 'outdec': 'lbw b Nisarg Patel', 'videotype': '', 'videourl': '', 'videoid': 0, 'planid': 0, 'imageid': 0, 'premiumvideourl': '', 'iscbplusfree': False, 'ispremiumfree': False, 'inmatchchange': '', 'isoverseas': False, 'playingxichange': ''}, {'id': 6710, 'balls': 5, 'runs': 10, 'fours': 2, 'sixes': 0, 'strkrate': '200', 'name': 'Balbirnie', 'nickname': '', 'iscaptain': True, 'iskeeper': False, 'outdec': 'c Sushant Modani b Netravalkar', 'videotype': '', 'videourl': '', 'videoid': 0, 'planid': 0, 'imageid': 0, 'premiumvideourl': '', 'iscbplusfree': False, 'ispremiumfree': False, 'inmatchchange': '', 'isoverseas': False, 'playingxichange': ''}, {'id': 11131, 'balls': 56, 'runs': 84, 'fours': 9, 'sixes': 3, 'strkrate': '150', 'name': 'Lorcan Tucker', 'nickname': '', 'iscaptain': False, 'iskeeper': Fals
# ...

# %%
Pcareer=[]
for data1 in data.get("values",[]):
  name=data1.get("name")
  debut=data1.get("debut")
  lastPlayed=data1.get("lastPlayed")
  debutMatchID=data1.get("debutMatchID")
  lastPlayedMatchId=data1.get("lastPlayedMatchId")

  Pcareer.append({
      "name": name ,
      "debut":debut ,
      "lastPlayed":lastPlayed,
      "debutMatchID": debutMatchID,
      "lastPlayedMatchId": lastPlayedMatchId
})

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/player/8733/bowling"

headers = {
	"x-rapidapi-key": "df0bd482a6mshb51dd03e9130c35p1ba9a3jsn359a8c907fc1",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'headers': ['ROWHEADER', 'Test', 'ODI', 'T20', 'IPL'], 'values': [{'values': ['Matches', '65', '88', '72', '145']}, {'values': ['Innings', '0', '0', '0', '0']}, {'values': ['Balls', '0', '0', '0', '0']}, {'values': ['Runs', '0', '0', '0', '0']}, {'values': ['Maidens', '0', '0', '0', '0']}, {'values': ['Wickets', '0', '0', '0', '0']}, {'values': ['Avg', '0.0', '0.0', '0.0', '0.0']}, {'values': ['Eco', '0', '0', '0', '0']}, {'values': ['SR', '0.0', '0.0', '0.0', '0.0']}, {'values': ['BBI', '-/-', '-/-', '-/-', '-/-']}, {'values': ['BBM', '-/-', '-/-', '-/-', '-/-']}, {'values': ['4w', '0', '0', '0', '0']}, {'values': ['5w', '0', '0', '0', '0']}, {'values': ['10w', '0', '0', '0', '0']}], 'appIndex': {'seoTitle': 'KL Rahul Profile - Cricbuzz | Cricbuzz.com', 'webURL': 'http://www.cricbuzz.com/profiles/8733/kl-rahul'}, 'seriesSpinner': [{'seriesName': 'Career'}]}

# %%
data=(response.json())
print(data)
# Out:
# {'headers': ['ROWHEADER', 'Test', 'ODI', 'T20', 'IPL'], 'values': [{'values': ['Matches', '65', '88', '72', '145']}, {'values': ['Innings', '0', '0', '0', '0']}, {'values': ['Balls', '0', '0', '0', '0']}, {'values': ['Runs', '0', '0', '0', '0']}, {'values': ['Maidens', '0', '0', '0', '0']}, {'values': ['Wickets', '0', '0', '0', '0']}, {'values': ['Avg', '0.0', '0.0', '0.0', '0.0']}, {'values': ['Eco', '0', '0', '0', '0']}, {'values': ['SR', '0.0', '0.0', '0.0', '0.0']}, {'values': ['BBI', '-/-', '-/-', '-/-', '-/-']}, {'values': ['BBM', '-/-', '-/-', '-/-', '-/-']}, {'values': ['4w', '0', '0', '0', '0']}, {'values': ['5w', '0', '0', '0', '0']}, {'values': ['10w', '0', '0', '0', '0']}], 'appIndex': {'seoTitle': 'KL Rahul Profile - Cricbuzz | Cricbuzz.com', 'webURL': 'http://www.cricbuzz.com/profiles/8733/kl-rahul'}, 'seriesSpinner': [{'seriesName': 'Career'}]}

# %%
data1=data.keys()
print(data1)
# Out:
# dict_keys(['headers', 'values', 'appIndex', 'seriesSpinner'])

# %%
data2=data['values']
print(data2)
# Out:
# [{'values': ['Matches', '65', '88', '72', '145']}, {'values': ['Innings', '0', '0', '0', '0']}, {'values': ['Balls', '0', '0', '0', '0']}, {'values': ['Runs', '0', '0', '0', '0']}, {'values': ['Maidens', '0', '0', '0', '0']}, {'values': ['Wickets', '0', '0', '0', '0']}, {'values': ['Avg', '0.0', '0.0', '0.0', '0.0']}, {'values': ['Eco', '0', '0', '0', '0']}, {'values': ['SR', '0.0', '0.0', '0.0', '0.0']}, {'values': ['BBI', '-/-', '-/-', '-/-', '-/-']}, {'values': ['BBM', '-/-', '-/-', '-/-', '-/-']}, {'values': ['4w', '0', '0', '0', '0']}, {'values': ['5w', '0', '0', '0', '0']}, {'values': ['10w', '0', '0', '0', '0']}]

# %%
data2 = data['values']

Bowling_result = { item['values'][0] : item['values'][1:] for item in data2 }

print(Bowling_result)
# Out:
# {'Matches': ['65', '88', '72', '145'], 'Innings': ['0', '0', '0', '0'], 'Balls': ['0', '0', '0', '0'], 'Runs': ['0', '0', '0', '0'], 'Maidens': ['0', '0', '0', '0'], 'Wickets': ['0', '0', '0', '0'], 'Avg': ['0.0', '0.0', '0.0', '0.0'], 'Eco': ['0', '0', '0', '0'], 'SR': ['0.0', '0.0', '0.0', '0.0'], 'BBI': ['-/-', '-/-', '-/-', '-/-'], 'BBM': ['-/-', '-/-', '-/-', '-/-'], '4w': ['0', '0', '0', '0'], '5w': ['0', '0', '0', '0'], '10w': ['0', '0', '0', '0']}

# %%
Bowling=[]
for data2 in data.get("values",[]):
  values=data2.get('values')
  
  Bowling.append({
      "values": values })

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/player/8733/batting"

headers = {
	"x-rapidapi-key": "df0bd482a6mshb51dd03e9130c35p1ba9a3jsn359a8c907fc1",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'headers': ['ROWHEADER', 'Test', 'ODI', 'T20', 'IPL'], 'values': [{'values': ['Matches', '65', '88', '72', '145']}, {'values': ['Innings', '114', '81', '68', '136']}, {'values': ['Runs', '3985', '3092', '2265', '5222']}, {'values': ['Balls', '7593', '3497', '1628', '3839']}, {'values': ['Highest', '199', '112', '110', '132']}, {'values': ['Average', '36.56', '48.31', '37.75', '46.21']}, {'values': ['SR', '52.49', '88.42', '139.13', '136.03']}, {'values': ['Not Out', '5', '17', '8', '23']}, {'values': ['Fours', '478', '238', '191', '452']}, {'values': ['Sixes', '29', '69', '99', '208']}, {'values': ['Ducks', '9', '3', '5', '4']}, {'values': ['50s', '20', '18', '22', '40']}, {'values': ['100s', '11', '7', '2', '5']}, {'values': ['200s', '0', '0', '0', '0']}, {'values': ['300s', '0', '0', '0', '0']}, {'values': ['400s', '0', '0', '0', '0']}], 'appIndex': {'seoTitle': 'KL Rahul Profile - Cricbuzz | Cricbuzz.com', 'webURL': 'http://www.cricbuzz.com/profiles/8733/kl-rahul'}, 'seriesSpinne
# ...

# %%
data=(response.json())
print(data)
# Out:
# {'headers': ['ROWHEADER', 'Test', 'ODI', 'T20', 'IPL'], 'values': [{'values': ['Matches', '65', '88', '72', '145']}, {'values': ['Innings', '114', '81', '68', '136']}, {'values': ['Runs', '3985', '3092', '2265', '5222']}, {'values': ['Balls', '7593', '3497', '1628', '3839']}, {'values': ['Highest', '199', '112', '110', '132']}, {'values': ['Average', '36.56', '48.31', '37.75', '46.21']}, {'values': ['SR', '52.49', '88.42', '139.13', '136.03']}, {'values': ['Not Out', '5', '17', '8', '23']}, {'values': ['Fours', '478', '238', '191', '452']}, {'values': ['Sixes', '29', '69', '99', '208']}, {'values': ['Ducks', '9', '3', '5', '4']}, {'values': ['50s', '20', '18', '22', '40']}, {'values': ['100s', '11', '7', '2', '5']}, {'values': ['200s', '0', '0', '0', '0']}, {'values': ['300s', '0', '0', '0', '0']}, {'values': ['400s', '0', '0', '0', '0']}], 'appIndex': {'seoTitle': 'KL Rahul Profile - Cricbuzz | Cricbuzz.com', 'webURL': 'http://www.cricbuzz.com/profiles/8733/kl-rahul'}, 'seriesSpinne
# ...

# %%
data1=data
print(data1.keys())
# Out:
# dict_keys(['headers', 'values', 'appIndex', 'seriesSpinner'])

# %%
data1=data['headers']
print(data1)
# Out:
# ['ROWHEADER', 'Test', 'ODI', 'T20', 'IPL']

# %%
Batting=[]
for data1 in data.get("headers",[]):
  for data1 in data.get("values",[]):
   values=data1.get('values')
  
  Batting.append({
      "values": values })

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/player/6635"

headers = {
	"x-rapidapi-key": "df0bd482a6mshb51dd03e9130c35p1ba9a3jsn359a8c907fc1",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'id': '6635', 'bat': 'Left Handed Bat', 'bowl': 'Right-arm offbreak', 'name': 'Usman Khawaja', 'nickName': 'Khawaja', 'height': '1.75 m ', 'role': 'Batsman', 'birthPlace': 'Islamabad, Pakistan ', 'intlTeam': 'Australia', 'teams': 'Australia, New South Wales, Derbyshire, Cricket Australia Chairmans XI, Sydney Thunder, Queensland, Australians, Australia A, Lancashire, Rising Pune Supergiant, Glamorgan, Islamabad United, Brisbane Heat', 'DoB': 'December 18, 1986 (38 years)', 'image': 'http://i.cricketcb.com/stats/img/faceImages/6635.jpg', 'bio': "Ricky Ponting's injury at Sydney in 2011, opened the doors for the first Muslim cricketer to represent Australia at the highest level. A qualified pilot, the highs of this achievement were unparalleled. Having moved to Australia as a kid, Usman Khawaja with the bat in his hands was identified pretty early as the boy wonder.  <br/>  <br/> Honing his skills at the Valley District Cricket Club, Usman made it to the Australian under-19 squad for t
# ...

# %%
data=(response.json())
print(data)
# Out:
# {'id': '6635', 'bat': 'Left Handed Bat', 'bowl': 'Right-arm offbreak', 'name': 'Usman Khawaja', 'nickName': 'Khawaja', 'height': '1.75 m ', 'role': 'Batsman', 'birthPlace': 'Islamabad, Pakistan ', 'intlTeam': 'Australia', 'teams': 'Australia, New South Wales, Derbyshire, Cricket Australia Chairmans XI, Sydney Thunder, Queensland, Australians, Australia A, Lancashire, Rising Pune Supergiant, Glamorgan, Islamabad United, Brisbane Heat', 'DoB': 'December 18, 1986 (38 years)', 'image': 'http://i.cricketcb.com/stats/img/faceImages/6635.jpg', 'bio': "Ricky Ponting's injury at Sydney in 2011, opened the doors for the first Muslim cricketer to represent Australia at the highest level. A qualified pilot, the highs of this achievement were unparalleled. Having moved to Australia as a kid, Usman Khawaja with the bat in his hands was identified pretty early as the boy wonder.  <br/>  <br/> Honing his skills at the Valley District Cricket Club, Usman made it to the Australian under-19 squad for t
# ...

# %%
data1=data
print(dict(data1))
# Out:
# {'headers': ['ROWHEADER', 'Test', 'ODI', 'T20', 'IPL'], 'values': [{'values': ['Matches', '65', '88', '72', '145']}, {'values': ['Innings', '114', '81', '68', '136']}, {'values': ['Runs', '3985', '3092', '2265', '5222']}, {'values': ['Balls', '7593', '3497', '1628', '3839']}, {'values': ['Highest', '199', '112', '110', '132']}, {'values': ['Average', '36.56', '48.31', '37.75', '46.21']}, {'values': ['SR', '52.49', '88.42', '139.13', '136.03']}, {'values': ['Not Out', '5', '17', '8', '23']}, {'values': ['Fours', '478', '238', '191', '452']}, {'values': ['Sixes', '29', '69', '99', '208']}, {'values': ['Ducks', '9', '3', '5', '4']}, {'values': ['50s', '20', '18', '22', '40']}, {'values': ['100s', '11', '7', '2', '5']}, {'values': ['200s', '0', '0', '0', '0']}, {'values': ['300s', '0', '0', '0', '0']}, {'values': ['400s', '0', '0', '0', '0']}], 'appIndex': {'seoTitle': 'KL Rahul Profile - Cricbuzz | Cricbuzz.com', 'webURL': 'http://www.cricbuzz.com/profiles/8733/kl-rahul'}, 'seriesSpinne
# ...

# %%
data_list = [data]
print(data_list)
# Out:
# [{'headers': ['ROWHEADER', 'Test', 'ODI', 'T20', 'IPL'], 'values': [{'values': ['Matches', '65', '88', '72', '145']}, {'values': ['Innings', '114', '81', '68', '136']}, {'values': ['Runs', '3985', '3092', '2265', '5222']}, {'values': ['Balls', '7593', '3497', '1628', '3839']}, {'values': ['Highest', '199', '112', '110', '132']}, {'values': ['Average', '36.56', '48.31', '37.75', '46.21']}, {'values': ['SR', '52.49', '88.42', '139.13', '136.03']}, {'values': ['Not Out', '5', '17', '8', '23']}, {'values': ['Fours', '478', '238', '191', '452']}, {'values': ['Sixes', '29', '69', '99', '208']}, {'values': ['Ducks', '9', '3', '5', '4']}, {'values': ['50s', '20', '18', '22', '40']}, {'values': ['100s', '11', '7', '2', '5']}, {'values': ['200s', '0', '0', '0', '0']}, {'values': ['300s', '0', '0', '0', '0']}, {'values': ['400s', '0', '0', '0', '0']}], 'appIndex': {'seoTitle': 'KL Rahul Profile - Cricbuzz | Cricbuzz.com', 'webURL': 'http://www.cricbuzz.com/profiles/8733/kl-rahul'}, 'seriesSpinn
# ...

# %%
data2=data1.keys()
print(data2)
# Out:
# dict_keys(['headers', 'values', 'appIndex', 'seriesSpinner'])

# %%
player_info = {
    "id": data.get("id"),
    "name": data.get("name"),
    "batting_style": data.get("bat"),
    "bowling_style": data.get("bowl"),
    "role": data.get("role"),
    "intlTeam": data.get("intlTeam"),
    "teams": data.get("teams"),
    "DoB": data.get("DoB"),
    "playerTeamIds": data.get("playerTeamIds"),
    "recentBatting": data.get("recentBatting"),
    "recentBowling": data.get("recentBowling")
}

# Convert into list
player_list = [player_info]

print(player_list)
# Out:
# [{'id': None, 'name': None, 'batting_style': None, 'bowling_style': None, 'role': None, 'intlTeam': None, 'teams': None, 'DoB': None, 'playerTeamIds': None, 'recentBatting': None, 'recentBowling': None}]

# %%
info1 = []   # list to store extracted player info

# Extract values from data1 (dict)
id = data1.get('id')
bat = data1.get('bat')
bowl = data1.get('bowl')
name = data1.get('name')
role = data1.get('role')
intlTeam = data1.get('intlTeam')
teams = data1.get('teams')
DoB = data1.get('DoB')
playerTeamIds = data1.get('playerTeamIds')
recentBatting = data1.get('recentBatting')
recentBowling = data1.get('recentBowling')

# Append into list as dict
info1.append({
    "id": id,
    "bat": bat,
    "bowl": bowl,
    "name": name,
    "role": role,
    "intlTeam": intlTeam,
    "teams": teams,
    "DoB": DoB,
    "playerTeamIds": playerTeamIds,
    "recentBatting": recentBatting,
    "recentBowling": recentBowling
})

print(info1)
# Out:
# [{'id': None, 'bat': None, 'bowl': None, 'name': None, 'role': None, 'intlTeam': None, 'teams': None, 'DoB': None, 'playerTeamIds': None, 'recentBatting': None, 'recentBowling': None}]

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/player/search"

querystring = {"plrN":"Tucker"}

headers = {
	"x-rapidapi-key": "df0bd482a6mshb51dd03e9130c35p1ba9a3jsn359a8c907fc1",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'player': [{'id': '674', 'name': 'Kwame Tucker', 'teamName': 'Bermuda', 'faceImageId': 155488, 'dob': '1976-09-28'}, {'id': '673', 'name': 'Janeiro Tucker', 'teamName': 'Bermuda', 'faceImageId': 155599, 'dob': '1975-03-15'}, {'id': '866', 'name': 'Tamauri Tucker', 'teamName': 'Bermuda', 'faceImageId': 155612, 'dob': '1988-12-10'}, {'id': '11131', 'name': 'Lorcan Tucker', 'teamName': 'Ireland', 'faceImageId': 244650, 'dob': '1996-09-10'}, {'id': '26178', 'name': 'Delmi Tucker', 'teamName': 'South Africa', 'faceImageId': 255000, 'dob': '1997-03-05'}, {'id': '7240', 'name': 'Rod Tucker', 'teamName': 'Australia', 'faceImageId': 182026, 'dob': '1964-08-28'}, {'id': '11123', 'name': 'Fiachra Tucker', 'teamName': 'Ireland', 'faceImageId': 182026, 'dob': 'N/A'}, {'id': '38265', 'name': 'Emily Tucker', 'teamName': 'Scotland', 'faceImageId': 182026, 'dob': 'N/A'}], 'category': 'Tucker'}

# %%
data=(response.json())
print(data)
# Out:
# {'player': [{'id': '674', 'name': 'Kwame Tucker', 'teamName': 'Bermuda', 'faceImageId': 155488, 'dob': '1976-09-28'}, {'id': '673', 'name': 'Janeiro Tucker', 'teamName': 'Bermuda', 'faceImageId': 155599, 'dob': '1975-03-15'}, {'id': '866', 'name': 'Tamauri Tucker', 'teamName': 'Bermuda', 'faceImageId': 155612, 'dob': '1988-12-10'}, {'id': '11131', 'name': 'Lorcan Tucker', 'teamName': 'Ireland', 'faceImageId': 244650, 'dob': '1996-09-10'}, {'id': '26178', 'name': 'Delmi Tucker', 'teamName': 'South Africa', 'faceImageId': 255000, 'dob': '1997-03-05'}, {'id': '7240', 'name': 'Rod Tucker', 'teamName': 'Australia', 'faceImageId': 182026, 'dob': '1964-08-28'}, {'id': '11123', 'name': 'Fiachra Tucker', 'teamName': 'Ireland', 'faceImageId': 182026, 'dob': 'N/A'}, {'id': '38265', 'name': 'Emily Tucker', 'teamName': 'Scotland', 'faceImageId': 182026, 'dob': 'N/A'}], 'category': 'Tucker'}

# %%
data1=data
print(data1.keys())
# Out:
# dict_keys(['player', 'category'])

# %%
data2=data1['player']
print(data2)
# Out:
# [{'id': '674', 'name': 'Kwame Tucker', 'teamName': 'Bermuda', 'faceImageId': 155488, 'dob': '1976-09-28'}, {'id': '673', 'name': 'Janeiro Tucker', 'teamName': 'Bermuda', 'faceImageId': 155599, 'dob': '1975-03-15'}, {'id': '866', 'name': 'Tamauri Tucker', 'teamName': 'Bermuda', 'faceImageId': 155612, 'dob': '1988-12-10'}, {'id': '11131', 'name': 'Lorcan Tucker', 'teamName': 'Ireland', 'faceImageId': 244650, 'dob': '1996-09-10'}, {'id': '26178', 'name': 'Delmi Tucker', 'teamName': 'South Africa', 'faceImageId': 255000, 'dob': '1997-03-05'}, {'id': '7240', 'name': 'Rod Tucker', 'teamName': 'Australia', 'faceImageId': 182026, 'dob': '1964-08-28'}, {'id': '11123', 'name': 'Fiachra Tucker', 'teamName': 'Ireland', 'faceImageId': 182026, 'dob': 'N/A'}, {'id': '38265', 'name': 'Emily Tucker', 'teamName': 'Scotland', 'faceImageId': 182026, 'dob': 'N/A'}]

# %%
data2=data1['player']
first_score=data2[0]
print(first_score)
# Out:
# {'id': '674', 'name': 'Kwame Tucker', 'teamName': 'Bermuda', 'faceImageId': 155488, 'dob': '1976-09-28'}

# %%
data = response.json()          # main dictionary
players = data.get('player', [])  # extract list using get()

print("Player count:", len(players))
# Out:
# Player count: 8

# %%
search = []

for player in players:
    # extract id, name, team from each player dict
    search.append({
        "id": player.get("id"),
        "name": player.get("name"),
        "team": player.get("teamName")
    })

print(search)
# Out:
# [{'id': '674', 'name': 'Kwame Tucker', 'team': 'Bermuda'}, {'id': '673', 'name': 'Janeiro Tucker', 'team': 'Bermuda'}, {'id': '866', 'name': 'Tamauri Tucker', 'team': 'Bermuda'}, {'id': '11131', 'name': 'Lorcan Tucker', 'team': 'Ireland'}, {'id': '26178', 'name': 'Delmi Tucker', 'team': 'South Africa'}, {'id': '7240', 'name': 'Rod Tucker', 'team': 'Australia'}, {'id': '11123', 'name': 'Fiachra Tucker', 'team': 'Ireland'}, {'id': '38265', 'name': 'Emily Tucker', 'team': 'Scotland'}]

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/venues/v1/45/matches"

headers = {
	"x-rapidapi-key": "df0bd482a6mshb51dd03e9130c35p1ba9a3jsn359a8c907fc1",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'matchDetails': [{'matchDetailsMap': {'key': 'The Ford Trophy 2025-26', 'match': [{'matchInfo': {'matchId': 131977, 'seriesId': 10724, 'seriesName': 'The Ford Trophy 2025-26', 'matchDesc': '11th Match', 'matchFormat': 'ODI', 'startDate': '1762551000000', 'endDate': '1762579800000', 'state': 'Upcoming', 'status': 'Match starts at Nov 08, 21:30 GMT', 'team1': {'teamId': 314, 'teamName': 'Wellington', 'teamSName': 'WEL', 'imageId': 172364}, 'team2': {'teamId': 105, 'teamName': 'Otago', 'teamSName': 'OTG', 'imageId': 172197}, 'venueInfo': {'id': 45, 'ground': 'Basin Reserve', 'city': 'Wellington', 'timezone': '+13:00'}, 'seriesStartDt': '1761350400000', 'seriesEndDt': '1771891200000', 'isTimeAnnounced': True}}, {'matchInfo': {'matchId': 132005, 'seriesId': 10724, 'seriesName': 'The Ford Trophy 2025-26', 'matchDesc': '14th Match', 'matchFormat': 'ODI', 'startDate': '1762896600000', 'endDate': '1762925400000', 'state': 'Upcoming', 'status': 'Match starts at Nov 12, 21:30 GMT', 'team1': {'
# ...

# %%
data=(response.json())
print(data)
# Out:
# {'matchDetails': [{'matchDetailsMap': {'key': 'The Ford Trophy 2025-26', 'match': [{'matchInfo': {'matchId': 131977, 'seriesId': 10724, 'seriesName': 'The Ford Trophy 2025-26', 'matchDesc': '11th Match', 'matchFormat': 'ODI', 'startDate': '1762551000000', 'endDate': '1762579800000', 'state': 'Upcoming', 'status': 'Match starts at Nov 08, 21:30 GMT', 'team1': {'teamId': 314, 'teamName': 'Wellington', 'teamSName': 'WEL', 'imageId': 172364}, 'team2': {'teamId': 105, 'teamName': 'Otago', 'teamSName': 'OTG', 'imageId': 172197}, 'venueInfo': {'id': 45, 'ground': 'Basin Reserve', 'city': 'Wellington', 'timezone': '+13:00'}, 'seriesStartDt': '1761350400000', 'seriesEndDt': '1771891200000', 'isTimeAnnounced': True}}, {'matchInfo': {'matchId': 132005, 'seriesId': 10724, 'seriesName': 'The Ford Trophy 2025-26', 'matchDesc': '14th Match', 'matchFormat': 'ODI', 'startDate': '1762896600000', 'endDate': '1762925400000', 'state': 'Upcoming', 'status': 'Match starts at Nov 12, 21:30 GMT', 'team1': {'
# ...

# %%
data1=data.keys()
print(data1)
# Out:
# dict_keys(['matchDetails', 'appIndex'])

# %%
data1=data['matchDetails']
print(data1)
# Out:
# [{'matchDetailsMap': {'key': 'The Ford Trophy 2025-26', 'match': [{'matchInfo': {'matchId': 131977, 'seriesId': 10724, 'seriesName': 'The Ford Trophy 2025-26', 'matchDesc': '11th Match', 'matchFormat': 'ODI', 'startDate': '1762551000000', 'endDate': '1762579800000', 'state': 'Upcoming', 'status': 'Match starts at Nov 08, 21:30 GMT', 'team1': {'teamId': 314, 'teamName': 'Wellington', 'teamSName': 'WEL', 'imageId': 172364}, 'team2': {'teamId': 105, 'teamName': 'Otago', 'teamSName': 'OTG', 'imageId': 172197}, 'venueInfo': {'id': 45, 'ground': 'Basin Reserve', 'city': 'Wellington', 'timezone': '+13:00'}, 'seriesStartDt': '1761350400000', 'seriesEndDt': '1771891200000', 'isTimeAnnounced': True}}, {'matchInfo': {'matchId': 132005, 'seriesId': 10724, 'seriesName': 'The Ford Trophy 2025-26', 'matchDesc': '14th Match', 'matchFormat': 'ODI', 'startDate': '1762896600000', 'endDate': '1762925400000', 'state': 'Upcoming', 'status': 'Match starts at Nov 12, 21:30 GMT', 'team1': {'teamId': 314, 'te
# ...

# %%
data1=data['matchDetails']
first_score=data1[0]
print(first_score['matchDetailsMap'])
# Out:
# {'key': 'The Ford Trophy 2025-26', 'match': [{'matchInfo': {'matchId': 131977, 'seriesId': 10724, 'seriesName': 'The Ford Trophy 2025-26', 'matchDesc': '11th Match', 'matchFormat': 'ODI', 'startDate': '1762551000000', 'endDate': '1762579800000', 'state': 'Upcoming', 'status': 'Match starts at Nov 08, 21:30 GMT', 'team1': {'teamId': 314, 'teamName': 'Wellington', 'teamSName': 'WEL', 'imageId': 172364}, 'team2': {'teamId': 105, 'teamName': 'Otago', 'teamSName': 'OTG', 'imageId': 172197}, 'venueInfo': {'id': 45, 'ground': 'Basin Reserve', 'city': 'Wellington', 'timezone': '+13:00'}, 'seriesStartDt': '1761350400000', 'seriesEndDt': '1771891200000', 'isTimeAnnounced': True}}, {'matchInfo': {'matchId': 132005, 'seriesId': 10724, 'seriesName': 'The Ford Trophy 2025-26', 'matchDesc': '14th Match', 'matchFormat': 'ODI', 'startDate': '1762896600000', 'endDate': '1762925400000', 'state': 'Upcoming', 'status': 'Match starts at Nov 12, 21:30 GMT', 'team1': {'teamId': 314, 'teamName': 'Wellington'
# ...

# %%
data1 = data.get('matchDetails', [])
print(data1)
# Out:
# [{'matchDetailsMap': {'key': 'The Ford Trophy 2025-26', 'match': [{'matchInfo': {'matchId': 131977, 'seriesId': 10724, 'seriesName': 'The Ford Trophy 2025-26', 'matchDesc': '11th Match', 'matchFormat': 'ODI', 'startDate': '1762551000000', 'endDate': '1762579800000', 'state': 'Upcoming', 'status': 'Match starts at Nov 08, 21:30 GMT', 'team1': {'teamId': 314, 'teamName': 'Wellington', 'teamSName': 'WEL', 'imageId': 172364}, 'team2': {'teamId': 105, 'teamName': 'Otago', 'teamSName': 'OTG', 'imageId': 172197}, 'venueInfo': {'id': 45, 'ground': 'Basin Reserve', 'city': 'Wellington', 'timezone': '+13:00'}, 'seriesStartDt': '1761350400000', 'seriesEndDt': '1771891200000', 'isTimeAnnounced': True}}, {'matchInfo': {'matchId': 132005, 'seriesId': 10724, 'seriesName': 'The Ford Trophy 2025-26', 'matchDesc': '14th Match', 'matchFormat': 'ODI', 'startDate': '1762896600000', 'endDate': '1762925400000', 'state': 'Upcoming', 'status': 'Match starts at Nov 12, 21:30 GMT', 'team1': {'teamId': 314, 'te
# ...

# %%
if len(data1) > 0:
    first_match = data1[0]
    venue = first_match.get('matchDetailsMap', {})

    print("key:", venue.get('key'))
    print("match:", venue.get('match', [])[0].get('matchInfo'))
    print("seriesId:", venue.get('seriesId'))
    print("seriesName:", venue.get('seriesName'))
    print("matchFormat:", venue.get('matchFormat'))
    print("state:", venue.get('state'))
    print("status:", venue.get('status'))
    print("team1:", venue.get('match', [])[0].get('matchInfo', {}).get('team1', {}).get('teamName'))
    print("team2:", venue.get('match', [])[0].get('matchInfo', {}).get('team2', {}).get('teamName'))
    print("venueInfo:", venue.get('venueInfo', {}).get('ground', {}).get('city'))

else:
    print("No match details found")
# Out:
# key: The Ford Trophy 2025-26
# match: {'matchId': 131977, 'seriesId': 10724, 'seriesName': 'The Ford Trophy 2025-26', 'matchDesc': '11th Match', 'matchFormat': 'ODI', 'startDate': '1762551000000', 'endDate': '1762579800000', 'state': 'Upcoming', 'status': 'Match starts at Nov 08, 21:30 GMT', 'team1': {'teamId': 314, 'teamName': 'Wellington', 'teamSName': 'WEL', 'imageId': 172364}, 'team2': {'teamId': 105, 'teamName': 'Otago', 'teamSName': 'OTG', 'imageId': 172197}, 'venueInfo': {'id': 45, 'ground': 'Basin Reserve', 'city': 'Wellington', 'timezone': '+13:00'}, 'seriesStartDt': '1761350400000', 'seriesEndDt': '1771891200000', 'isTimeAnnounced': True}
# seriesId: 10724
# seriesName: None
# matchFormat: None
# state: None
# status: None
# team1: Wellington
# team2: Otago
# venueInfo: None

# %%
stats records

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/topstats/0"

querystring = {"statsType":"mostRuns"}

headers = {
	"x-rapidapi-key": "df0bd482a6mshb51dd03e9130c35p1ba9a3jsn359a8c907fc1",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'filter': {'matchtype': [{'matchTypeId': '1', 'matchTypeDesc': 'test'}, {'matchTypeId': '2', 'matchTypeDesc': 'odi'}, {'matchTypeId': '3', 'matchTypeDesc': 't20'}], 'team': [{'id': '96', 'teamShortName': 'AFG'}, {'id': '13', 'teamShortName': 'NZ'}, {'id': '12', 'teamShortName': 'ZIM'}, {'id': '11', 'teamShortName': 'RSA'}, {'id': '10', 'teamShortName': 'WI'}, {'id': '9', 'teamShortName': 'ENG'}, {'id': '6', 'teamShortName': 'BAN'}, {'id': '5', 'teamShortName': 'SL'}, {'id': '4', 'teamShortName': 'AUS'}, {'id': '3', 'teamShortName': 'PAK'}, {'id': '27', 'teamShortName': 'IRE'}, {'id': '2', 'teamShortName': 'IND'}], 'selectedMatchType': 'test'}, 'headers': ['Batter', 'M', 'I', 'R', 'Avg'], 'values': [{'values': ['25', 'Tendulkar', '200', '329', '15921', '53.79']}, {'values': ['8019', 'Root', '158', '288', '13543', '51.30']}, {'values': ['38', 'R Ponting', '168', '287', '13378', '51.85']}, {'values': ['213', 'Kallis', '166', '280', '13289', '55.37']}, {'values': ['27', 'Dravid', '164',
# ...

# %%
data=(response.json())
print(data)
# Out:
# {'filter': {'matchtype': [{'matchTypeId': '1', 'matchTypeDesc': 'test'}, {'matchTypeId': '2', 'matchTypeDesc': 'odi'}, {'matchTypeId': '3', 'matchTypeDesc': 't20'}], 'team': [{'id': '96', 'teamShortName': 'AFG'}, {'id': '13', 'teamShortName': 'NZ'}, {'id': '12', 'teamShortName': 'ZIM'}, {'id': '11', 'teamShortName': 'RSA'}, {'id': '10', 'teamShortName': 'WI'}, {'id': '9', 'teamShortName': 'ENG'}, {'id': '6', 'teamShortName': 'BAN'}, {'id': '5', 'teamShortName': 'SL'}, {'id': '4', 'teamShortName': 'AUS'}, {'id': '3', 'teamShortName': 'PAK'}, {'id': '27', 'teamShortName': 'IRE'}, {'id': '2', 'teamShortName': 'IND'}], 'selectedMatchType': 'test'}, 'headers': ['Batter', 'M', 'I', 'R', 'Avg'], 'values': [{'values': ['25', 'Tendulkar', '200', '329', '15921', '53.79']}, {'values': ['8019', 'Root', '158', '288', '13543', '51.30']}, {'values': ['38', 'R Ponting', '168', '287', '13378', '51.85']}, {'values': ['213', 'Kallis', '166', '280', '13289', '55.37']}, {'values': ['27', 'Dravid', '164',
# ...

# %%
data2 =data.get

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/matches/v1/upcoming"

headers = {
	"x-rapidapi-key": "bf10e75c34mshe29d2ac7bca38cep143477jsn19fd2ab2770f",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'typeMatches': [{'matchType': 'International', 'seriesMatches': [{'seriesAdWrapper': {'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matches': [{'matchInfo': {'matchId': 116936, 'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matchDesc': '1st T20I', 'matchFormat': 'T20', 'startDate': '1761725700000', 'endDate': '1761738300000', 'state': 'Preview', 'status': 'Match starts at Oct 29, 08:15 GMT', 'team1': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 776202}, 'team2': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 776162}, 'venueInfo': {'id': 123, 'ground': 'Manuka Oval', 'city': 'Canberra', 'timezone': '+11:00', 'latitude': '-35.318630', 'longitude': '149.136703'}, 'seriesStartDt': '1760832000000', 'seriesEndDt': '1762732800000', 'isTimeAnnounced': True, 'stateTitle': 'Preview'}}]}}, {'seriesAdWrapper': {'seriesId': 10895, 'seriesName': 'South Africa tour of Pakistan, 2025', 'matches': [{'matchInfo': {'mat
# ...

# %%
data=(response.json())
print(data)
# Out:
# {'typeMatches': [{'matchType': 'International', 'seriesMatches': [{'seriesAdWrapper': {'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matches': [{'matchInfo': {'matchId': 116936, 'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matchDesc': '1st T20I', 'matchFormat': 'T20', 'startDate': '1761725700000', 'endDate': '1761738300000', 'state': 'Preview', 'status': 'Match starts at Oct 29, 08:15 GMT', 'team1': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 776202}, 'team2': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 776162}, 'venueInfo': {'id': 123, 'ground': 'Manuka Oval', 'city': 'Canberra', 'timezone': '+11:00', 'latitude': '-35.318630', 'longitude': '149.136703'}, 'seriesStartDt': '1760832000000', 'seriesEndDt': '1762732800000', 'isTimeAnnounced': True, 'stateTitle': 'Preview'}}]}}, {'seriesAdWrapper': {'seriesId': 10895, 'seriesName': 'South Africa tour of Pakistan, 2025', 'matches': [{'matchInfo': {'mat
# ...

# %%
data.keys()
print(data)
# Out:
# {'typeMatches': [{'matchType': 'International', 'seriesMatches': [{'seriesAdWrapper': {'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matches': [{'matchInfo': {'matchId': 116936, 'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matchDesc': '1st T20I', 'matchFormat': 'T20', 'startDate': '1761725700000', 'endDate': '1761738300000', 'state': 'Preview', 'status': 'Match starts at Oct 29, 08:15 GMT', 'team1': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 776202}, 'team2': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 776162}, 'venueInfo': {'id': 123, 'ground': 'Manuka Oval', 'city': 'Canberra', 'timezone': '+11:00', 'latitude': '-35.318630', 'longitude': '149.136703'}, 'seriesStartDt': '1760832000000', 'seriesEndDt': '1762732800000', 'isTimeAnnounced': True, 'stateTitle': 'Preview'}}]}}, {'seriesAdWrapper': {'seriesId': 10895, 'seriesName': 'South Africa tour of Pakistan, 2025', 'matches': [{'matchInfo': {'mat
# ...

# %%
type=data['typeMatches']
print(type)
# Out:
# [{'matchType': 'International', 'seriesMatches': [{'seriesAdWrapper': {'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matches': [{'matchInfo': {'matchId': 116936, 'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matchDesc': '1st T20I', 'matchFormat': 'T20', 'startDate': '1761725700000', 'endDate': '1761738300000', 'state': 'Preview', 'status': 'Match starts at Oct 29, 08:15 GMT', 'team1': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 776202}, 'team2': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 776162}, 'venueInfo': {'id': 123, 'ground': 'Manuka Oval', 'city': 'Canberra', 'timezone': '+11:00', 'latitude': '-35.318630', 'longitude': '149.136703'}, 'seriesStartDt': '1760832000000', 'seriesEndDt': '1762732800000', 'isTimeAnnounced': True, 'stateTitle': 'Preview'}}]}}, {'seriesAdWrapper': {'seriesId': 10895, 'seriesName': 'South Africa tour of Pakistan, 2025', 'matches': [{'matchInfo': {'matchId': 134370, '
# ...

# %%
type[0]['seriesMatches']
# Out:
# [{'seriesAdWrapper': {'seriesId': 9596,
#    'seriesName': 'India tour of Australia, 2025',
#    'matches': [{'matchInfo': {'matchId': 116936,
#       'seriesId': 9596,
#       'seriesName': 'India tour of Australia, 2025',
#       'matchDesc': '1st T20I',
#       'matchFormat': 'T20',
#       'startDate': '1761725700000',
#       'endDate': '1761738300000',
#       'state': 'Preview',
#       'status': 'Match starts at Oct 29, 08:15 GMT',
#       'team1': {'teamId': 4,
#        'teamName': 'Australia',
#        'teamSName': 'AUS',
#        'imageId': 776202},
#       'team2': {'teamId': 2,
#        'teamName': 'India',
#        'teamSName': 'IND',
#        'imageId': 776162},
#       'venueInfo': {'id': 123,
#        'ground': 'Manuka Oval',
#        'city': 'Canberra',
#        'timezone': '+11:00',
#        'latitude': '-35.318630',
#        'longitude': '149.136703'},
#       'seriesStartDt': '1760832000000',
#       'seriesEndDt': '1762732800000',
# ...

# %%
data_type=type[0].keys()
print(data_type)
# Out:
# dict_keys(['matchType', 'seriesMatches'])

# %%
Series_match=type[0]['seriesMatches']
print(Series_match)
# Out:
# [{'seriesAdWrapper': {'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matches': [{'matchInfo': {'matchId': 116936, 'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matchDesc': '1st T20I', 'matchFormat': 'T20', 'startDate': '1761725700000', 'endDate': '1761738300000', 'state': 'Preview', 'status': 'Match starts at Oct 29, 08:15 GMT', 'team1': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 776202}, 'team2': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 776162}, 'venueInfo': {'id': 123, 'ground': 'Manuka Oval', 'city': 'Canberra', 'timezone': '+11:00', 'latitude': '-35.318630', 'longitude': '149.136703'}, 'seriesStartDt': '1760832000000', 'seriesEndDt': '1762732800000', 'isTimeAnnounced': True, 'stateTitle': 'Preview'}}]}}, {'seriesAdWrapper': {'seriesId': 10895, 'seriesName': 'South Africa tour of Pakistan, 2025', 'matches': [{'matchInfo': {'matchId': 134370, 'seriesId': 10895, 'seriesName': 'South Africa tou
# ...

# %%
series_wrapper=Series_match[0]['seriesAdWrapper']
print(series_wrapper.keys())
# Out:
# dict_keys(['seriesId', 'seriesName', 'matches'])

# %%
stream=series_wrapper['matches']
print(stream)
# Out:
# [{'matchInfo': {'matchId': 116936, 'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matchDesc': '1st T20I', 'matchFormat': 'T20', 'startDate': '1761725700000', 'endDate': '1761738300000', 'state': 'Preview', 'status': 'Match starts at Oct 29, 08:15 GMT', 'team1': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 776202}, 'team2': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 776162}, 'venueInfo': {'id': 123, 'ground': 'Manuka Oval', 'city': 'Canberra', 'timezone': '+11:00', 'latitude': '-35.318630', 'longitude': '149.136703'}, 'seriesStartDt': '1760832000000', 'seriesEndDt': '1762732800000', 'isTimeAnnounced': True, 'stateTitle': 'Preview'}}]

# %%
match_info=stream[0]
print(match_info.keys())
# Out:
# dict_keys(['matchInfo'])

# %%
upcoming=series_wrapper['matches']
first_match=upcoming[0]
print(first_match['matchInfo'])
# Out:
# {'matchId': 116936, 'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matchDesc': '1st T20I', 'matchFormat': 'T20', 'startDate': '1761725700000', 'endDate': '1761738300000', 'state': 'Preview', 'status': 'Match starts at Oct 29, 08:15 GMT', 'team1': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 776202}, 'team2': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 776162}, 'venueInfo': {'id': 123, 'ground': 'Manuka Oval', 'city': 'Canberra', 'timezone': '+11:00', 'latitude': '-35.318630', 'longitude': '149.136703'}, 'seriesStartDt': '1760832000000', 'seriesEndDt': '1762732800000', 'isTimeAnnounced': True, 'stateTitle': 'Preview'}

# %%
live_stream=first_match['matchInfo']
print("matchId",live_stream['matchId'])
print("seriesId",live_stream['seriesId'])
print("seriesName",live_stream['seriesName'])
print("matchDesc",live_stream['matchDesc'])
print("matchFormat",live_stream['matchFormat'])
print("startDate",live_stream['startDate'])
print("endDate",live_stream['endDate'])
print("state",live_stream['state'])
print("status",live_stream['status'])

print("team1",live_stream['team1']['teamSName'])
print("team2",live_stream['team2']['teamSName'])

print("venueInfo",live_stream['venueInfo']['ground'])
# Out:
# matchId 116936
# seriesId 9596
# seriesName India tour of Australia, 2025
# matchDesc 1st T20I
# matchFormat T20
# startDate 1761725700000
# endDate 1761738300000
# state Preview
# status Match starts at Oct 29, 08:15 GMT
# team1 AUS
# team2 IND
# venueInfo Manuka Oval

# %%
matches=[]
for type in data.get("typeMatches", []):
    for series_match in type_match.get("seriesMatches", []):
        series_data = series_match.get("seriesAdWrapper", {})
        series_id = series_data.get("seriesId")
        series_name = series_data.get("seriesName")

        for match in series_data.get("matches", []):
            info = match.get("matchInfo", {})
            match_id = info.get("matchId")
            match_desc = info.get("matchDesc")
            match_format = info.get("matchFormat")
            start_date = info.get("startDate")
            state=info.get('state')
            status = info.get("status")
            team1 = info.get("team1", {}).get("teamName")
            team2 = info.get("team2", {}).get("teamName")
            city=info.get("venueInfo", {}).get("city"),
            score=match.get('matchScore',{})
            venue_info=info.get("venueInfo", {}).get('city')          


            matches.append({
                "series_id": series_id,
                "series_name": series_name,
                "match_id": match_id,
                "desc": match_desc,
                "match_format": match_format,
                "team1": team1,
                "team2": team2,
                "venue": venue_info,
                "city":city, 
                "status": status,
                'score':score, 
                "state":state 
            })

# %%
matches list

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/matches/v1/recent"

headers = {
	"x-rapidapi-key": "df0bd482a6mshb51dd03e9130c35p1ba9a3jsn359a8c907fc1",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'typeMatches': [{'matchType': 'International', 'seriesMatches': [{'seriesAdWrapper': {'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matches': [{'matchInfo': {'matchId': 116954, 'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matchDesc': '3rd T20I', 'matchFormat': 'T20', 'startDate': '1762071300000', 'endDate': '1762083900000', 'state': 'Complete', 'status': 'India won by 5 wkts', 'team1': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 776202}, 'team2': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 776162}, 'venueInfo': {'id': 39, 'ground': 'Bellerive Oval', 'city': 'Hobart', 'timezone': '+11:00', 'latitude': '-42.877296', 'longitude': '147.374013'}, 'currBatTeamId': 2, 'seriesStartDt': '1760832000000', 'seriesEndDt': '1762732800000', 'isTimeAnnounced': True, 'stateTitle': 'IND Won'}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 186, 'wickets': 6, 'overs': 19.6}}, 'team2Score': {'inng
# ...

# %%
data=(response.json())
print(data)
# Out:
# {'typeMatches': [{'matchType': 'International', 'seriesMatches': [{'seriesAdWrapper': {'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matches': [{'matchInfo': {'matchId': 116954, 'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matchDesc': '3rd T20I', 'matchFormat': 'T20', 'startDate': '1762071300000', 'endDate': '1762083900000', 'state': 'Complete', 'status': 'India won by 5 wkts', 'team1': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 776202}, 'team2': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 776162}, 'venueInfo': {'id': 39, 'ground': 'Bellerive Oval', 'city': 'Hobart', 'timezone': '+11:00', 'latitude': '-42.877296', 'longitude': '147.374013'}, 'currBatTeamId': 2, 'seriesStartDt': '1760832000000', 'seriesEndDt': '1762732800000', 'isTimeAnnounced': True, 'stateTitle': 'IND Won'}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 186, 'wickets': 6, 'overs': 19.6}}, 'team2Score': {'inng
# ...

# %%
data1=data.keys()
print(data1)
# Out:
# dict_keys(['typeMatches', 'filters', 'appIndex', 'responseLastUpdated'])

# %%
data1=data['typeMatches']
print(data1)
# Out:
# [{'matchType': 'International', 'seriesMatches': [{'seriesAdWrapper': {'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matches': [{'matchInfo': {'matchId': 116954, 'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matchDesc': '3rd T20I', 'matchFormat': 'T20', 'startDate': '1762071300000', 'endDate': '1762083900000', 'state': 'Complete', 'status': 'India won by 5 wkts', 'team1': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 776202}, 'team2': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 776162}, 'venueInfo': {'id': 39, 'ground': 'Bellerive Oval', 'city': 'Hobart', 'timezone': '+11:00', 'latitude': '-42.877296', 'longitude': '147.374013'}, 'currBatTeamId': 2, 'seriesStartDt': '1760832000000', 'seriesEndDt': '1762732800000', 'isTimeAnnounced': True, 'stateTitle': 'IND Won'}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 186, 'wickets': 6, 'overs': 19.6}}, 'team2Score': {'inngs1': {'inningsId
# ...

# %%
match_info=data1[0]
print(match_info.keys())
# Out:
# dict_keys(['matchType', 'seriesMatches'])

# %%
Matchinfo=data1[1]
print(match_info)
# Out:
# {'matchType': 'International', 'seriesMatches': [{'seriesAdWrapper': {'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matches': [{'matchInfo': {'matchId': 116954, 'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matchDesc': '3rd T20I', 'matchFormat': 'T20', 'startDate': '1762071300000', 'endDate': '1762083900000', 'state': 'Complete', 'status': 'India won by 5 wkts', 'team1': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 776202}, 'team2': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 776162}, 'venueInfo': {'id': 39, 'ground': 'Bellerive Oval', 'city': 'Hobart', 'timezone': '+11:00', 'latitude': '-42.877296', 'longitude': '147.374013'}, 'currBatTeamId': 2, 'seriesStartDt': '1760832000000', 'seriesEndDt': '1762732800000', 'isTimeAnnounced': True, 'stateTitle': 'IND Won'}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 186, 'wickets': 6, 'overs': 19.6}}, 'team2Score': {'inngs1': {'inningsId'
# ...

# %%
match_list=match_info['seriesMatches']
print(match_list)
# Out:
# [{'seriesAdWrapper': {'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matches': [{'matchInfo': {'matchId': 116954, 'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matchDesc': '3rd T20I', 'matchFormat': 'T20', 'startDate': '1762071300000', 'endDate': '1762083900000', 'state': 'Complete', 'status': 'India won by 5 wkts', 'team1': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 776202}, 'team2': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 776162}, 'venueInfo': {'id': 39, 'ground': 'Bellerive Oval', 'city': 'Hobart', 'timezone': '+11:00', 'latitude': '-42.877296', 'longitude': '147.374013'}, 'currBatTeamId': 2, 'seriesStartDt': '1760832000000', 'seriesEndDt': '1762732800000', 'isTimeAnnounced': True, 'stateTitle': 'IND Won'}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 186, 'wickets': 6, 'overs': 19.6}}, 'team2Score': {'inngs1': {'inningsId': 2, 'runs': 188, 'wickets': 5, 'overs': 18.3}}}
# ...

# %%
match_list1=match_list[0]['seriesAdWrapper']
print(match_list1)
# Out:
# {'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matches': [{'matchInfo': {'matchId': 116954, 'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matchDesc': '3rd T20I', 'matchFormat': 'T20', 'startDate': '1762071300000', 'endDate': '1762083900000', 'state': 'Complete', 'status': 'India won by 5 wkts', 'team1': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 776202}, 'team2': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 776162}, 'venueInfo': {'id': 39, 'ground': 'Bellerive Oval', 'city': 'Hobart', 'timezone': '+11:00', 'latitude': '-42.877296', 'longitude': '147.374013'}, 'currBatTeamId': 2, 'seriesStartDt': '1760832000000', 'seriesEndDt': '1762732800000', 'isTimeAnnounced': True, 'stateTitle': 'IND Won'}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 186, 'wickets': 6, 'overs': 19.6}}, 'team2Score': {'inngs1': {'inningsId': 2, 'runs': 188, 'wickets': 5, 'overs': 18.3}}}}, {'matchInfo': {'ma
# ...

# %%
match_list2=match_list1['matches']
print(match_list2)
# Out:
# [{'matchInfo': {'matchId': 116954, 'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matchDesc': '3rd T20I', 'matchFormat': 'T20', 'startDate': '1762071300000', 'endDate': '1762083900000', 'state': 'Complete', 'status': 'India won by 5 wkts', 'team1': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 776202}, 'team2': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 776162}, 'venueInfo': {'id': 39, 'ground': 'Bellerive Oval', 'city': 'Hobart', 'timezone': '+11:00', 'latitude': '-42.877296', 'longitude': '147.374013'}, 'currBatTeamId': 2, 'seriesStartDt': '1760832000000', 'seriesEndDt': '1762732800000', 'isTimeAnnounced': True, 'stateTitle': 'IND Won'}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 186, 'wickets': 6, 'overs': 19.6}}, 'team2Score': {'inngs1': {'inningsId': 2, 'runs': 188, 'wickets': 5, 'overs': 18.3}}}}, {'matchInfo': {'matchId': 116945, 'seriesId': 9596, 'seriesName': 'India tour of Australia, 202
# ...

# %%
matches_list=match_list2[0]['matchInfo']
print(matches_list.keys())
# Out:
# dict_keys(['matchId', 'seriesId', 'seriesName', 'matchDesc', 'matchFormat', 'startDate', 'endDate', 'state', 'status', 'team1', 'team2', 'venueInfo', 'currBatTeamId', 'seriesStartDt', 'seriesEndDt', 'isTimeAnnounced', 'stateTitle'])

# %%
match_information=match_list1['matches']
first_match=match_information[0]
print(first_match['matchInfo'])
# Out:
# {'matchId': 116954, 'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matchDesc': '3rd T20I', 'matchFormat': 'T20', 'startDate': '1762071300000', 'endDate': '1762083900000', 'state': 'Complete', 'status': 'India won by 5 wkts', 'team1': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 776202}, 'team2': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 776162}, 'venueInfo': {'id': 39, 'ground': 'Bellerive Oval', 'city': 'Hobart', 'timezone': '+11:00', 'latitude': '-42.877296', 'longitude': '147.374013'}, 'currBatTeamId': 2, 'seriesStartDt': '1760832000000', 'seriesEndDt': '1762732800000', 'isTimeAnnounced': True, 'stateTitle': 'IND Won'}

# %%
Match_details =first_match['matchInfo']
print("matchId",Match_details['matchId'])
print("seriesId",Match_details['seriesId'])
print("seriesName",Match_details['seriesName'])
print("matchDesc",Match_details['matchDesc'])
print("matchFormat",Match_details['matchFormat'])
print("startDate",Match_details['startDate'])
print("endDate",Match_details['endDate'])
print("state",Match_details['state'])
print("status",Match_details['status'])
print("currBatTeamId",Match_details['currBatTeamId'])
print("seriesStartDt",Match_details['seriesStartDt'])
print("seriesEndDt",Match_details['seriesEndDt'])


print("team1",Match_details['team1']['teamSName'])
print("team2",Match_details['team2']['teamSName'])

print("venueInfo",Match_details['venueInfo']['ground'])
# Out:
# matchId 116954
# seriesId 9596
# seriesName India tour of Australia, 2025
# matchDesc 3rd T20I
# matchFormat T20
# startDate 1762071300000
# endDate 1762083900000
# state Complete
# status India won by 5 wkts
# currBatTeamId 2
# seriesStartDt 1760832000000
# seriesEndDt 1762732800000
# team1 AUS
# team2 IND
# venueInfo Bellerive Oval

# %%
matches_list = []

for type_block in data.get("typeMatches", []):
    for series_block in type_block.get("seriesMatches", []):
        wrapper = series_block.get("seriesAdWrapper", {})

        seriesName = wrapper.get("seriesName")
        for match in wrapper.get("matches", []):
            
            info = match.get("matchInfo", {})

            matches_list.append({
                "matchId": info.get("matchId"),
                "seriesId": info.get("seriesId"),
                "seriesName": seriesName,
                "matchDesc": info.get("matchDesc"),
                "matchFormat": info.get("matchFormat"),
                "startDate": info.get("startDate"),
                "endDate": info.get("endDate"),
                "state": info.get("state"),
                "status": info.get("status"),
                "currBatTeamId": info.get("currBatTeamId"),
                "team1": info.get("team1", {}).get("teamName"),
                "team2": info.get("team2", {}).get("teamName"),
                "venue": info.get("venueInfo", {}).get("ground"),
                "city": info.get("venueInfo", {}).get("city"),
            })

print(matches_list)
# Out:
# [{'matchId': 116954, 'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matchDesc': '3rd T20I', 'matchFormat': 'T20', 'startDate': '1762071300000', 'endDate': '1762083900000', 'state': 'Complete', 'status': 'India won by 5 wkts', 'currBatTeamId': 2, 'team1': 'Australia', 'team2': 'India', 'venue': 'Bellerive Oval', 'city': 'Hobart'}, {'matchId': 116945, 'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matchDesc': '2nd T20I ', 'matchFormat': 'T20', 'startDate': '1761898500000', 'endDate': '1761911100000', 'state': 'Complete', 'status': 'Australia won by 4 wkts', 'currBatTeamId': 4, 'team1': 'India', 'team2': 'Australia', 'venue': 'Melbourne Cricket Ground', 'city': 'Melbourne'}, {'matchId': 116936, 'seriesId': 9596, 'seriesName': 'India tour of Australia, 2025', 'matchDesc': '1st T20I', 'matchFormat': 'T20', 'startDate': '1761725700000', 'endDate': '1761738300000', 'state': 'Complete', 'status': 'No result (due to rain)', 'currBatTeamId': None, 'team1':
# ...

# %%
Score card

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/mcenter/v1/40381/scard"

headers = {
	"x-rapidapi-key": "df0bd482a6mshb51dd03e9130c35p1ba9a3jsn359a8c907fc1",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'scorecard': [{'inningsid': 1, 'batsman': [{'id': 1114, 'balls': 5, 'runs': 5, 'fours': 1, 'sixes': 0, 'strkrate': '100', 'name': 'Stirling', 'nickname': '', 'iscaptain': False, 'iskeeper': False, 'outdec': 'lbw b Nisarg Patel', 'videotype': '', 'videourl': '', 'videoid': 0, 'planid': 0, 'imageid': 0, 'premiumvideourl': '', 'iscbplusfree': False, 'ispremiumfree': False, 'inmatchchange': '', 'isoverseas': False, 'playingxichange': ''}, {'id': 6710, 'balls': 5, 'runs': 10, 'fours': 2, 'sixes': 0, 'strkrate': '200', 'name': 'Balbirnie', 'nickname': '', 'iscaptain': True, 'iskeeper': False, 'outdec': 'c Sushant Modani b Netravalkar', 'videotype': '', 'videourl': '', 'videoid': 0, 'planid': 0, 'imageid': 0, 'premiumvideourl': '', 'iscbplusfree': False, 'ispremiumfree': False, 'inmatchchange': '', 'isoverseas': False, 'playingxichange': ''}, {'id': 11131, 'balls': 56, 'runs': 84, 'fours': 9, 'sixes': 3, 'strkrate': '150', 'name': 'Lorcan Tucker', 'nickname': '', 'iscaptain': False, 'iskee
# ...

# %%
data=(response.json())
print(data)
# Out:
# {'scorecard': [{'inningsid': 1, 'batsman': [{'id': 1114, 'balls': 5, 'runs': 5, 'fours': 1, 'sixes': 0, 'strkrate': '100', 'name': 'Stirling', 'nickname': '', 'iscaptain': False, 'iskeeper': False, 'outdec': 'lbw b Nisarg Patel', 'videotype': '', 'videourl': '', 'videoid': 0, 'planid': 0, 'imageid': 0, 'premiumvideourl': '', 'iscbplusfree': False, 'ispremiumfree': False, 'inmatchchange': '', 'isoverseas': False, 'playingxichange': ''}, {'id': 6710, 'balls': 5, 'runs': 10, 'fours': 2, 'sixes': 0, 'strkrate': '200', 'name': 'Balbirnie', 'nickname': '', 'iscaptain': True, 'iskeeper': False, 'outdec': 'c Sushant Modani b Netravalkar', 'videotype': '', 'videourl': '', 'videoid': 0, 'planid': 0, 'imageid': 0, 'premiumvideourl': '', 'iscbplusfree': False, 'ispremiumfree': False, 'inmatchchange': '', 'isoverseas': False, 'playingxichange': ''}, {'id': 11131, 'balls': 56, 'runs': 84, 'fours': 9, 'sixes': 3, 'strkrate': '150', 'name': 'Lorcan Tucker', 'nickname': '', 'iscaptain': False, 'iskee
# ...

# %%
data1=data.keys()
print(data1)
# Out:
# dict_keys(['scorecard', 'ismatchcomplete', 'appindex', 'status', 'responselastupdated'])

# %%
data1=data['scorecard']
print(data1)
# Out:
# [{'inningsid': 1, 'batsman': [{'id': 1114, 'balls': 5, 'runs': 5, 'fours': 1, 'sixes': 0, 'strkrate': '100', 'name': 'Stirling', 'nickname': '', 'iscaptain': False, 'iskeeper': False, 'outdec': 'lbw b Nisarg Patel', 'videotype': '', 'videourl': '', 'videoid': 0, 'planid': 0, 'imageid': 0, 'premiumvideourl': '', 'iscbplusfree': False, 'ispremiumfree': False, 'inmatchchange': '', 'isoverseas': False, 'playingxichange': ''}, {'id': 6710, 'balls': 5, 'runs': 10, 'fours': 2, 'sixes': 0, 'strkrate': '200', 'name': 'Balbirnie', 'nickname': '', 'iscaptain': True, 'iskeeper': False, 'outdec': 'c Sushant Modani b Netravalkar', 'videotype': '', 'videourl': '', 'videoid': 0, 'planid': 0, 'imageid': 0, 'premiumvideourl': '', 'iscbplusfree': False, 'ispremiumfree': False, 'inmatchchange': '', 'isoverseas': False, 'playingxichange': ''}, {'id': 11131, 'balls': 56, 'runs': 84, 'fours': 9, 'sixes': 3, 'strkrate': '150', 'name': 'Lorcan Tucker', 'nickname': '', 'iscaptain': False, 'iskeeper': False, '
# ...

# %%
data2=data.keys()
print(data2)
# Out:
# dict_keys(['scorecard', 'ismatchcomplete', 'appindex', 'status', 'responselastupdated'])

# %%
data2=data['appindex']
print(data2)
# Out:
# {'seotitle': 'Cricket scorecard - USA vs IRE 2nd T20I,Ireland tour of USA, 2021 | Cricbuzz.com', 'weburl': 'http://www.cricbuzz.com/live-cricket-scorecard/40381/usa-vs-ire-2nd-t20i-ireland-tour-of-usa-2021'}

# %%
data3=data['scorecard']
first_score=data3[0]
print(first_score['batsman'])
# Out:
# [{'id': 1114, 'balls': 5, 'runs': 5, 'fours': 1, 'sixes': 0, 'strkrate': '100', 'name': 'Stirling', 'nickname': '', 'iscaptain': False, 'iskeeper': False, 'outdec': 'lbw b Nisarg Patel', 'videotype': '', 'videourl': '', 'videoid': 0, 'planid': 0, 'imageid': 0, 'premiumvideourl': '', 'iscbplusfree': False, 'ispremiumfree': False, 'inmatchchange': '', 'isoverseas': False, 'playingxichange': ''}, {'id': 6710, 'balls': 5, 'runs': 10, 'fours': 2, 'sixes': 0, 'strkrate': '200', 'name': 'Balbirnie', 'nickname': '', 'iscaptain': True, 'iskeeper': False, 'outdec': 'c Sushant Modani b Netravalkar', 'videotype': '', 'videourl': '', 'videoid': 0, 'planid': 0, 'imageid': 0, 'premiumvideourl': '', 'iscbplusfree': False, 'ispremiumfree': False, 'inmatchchange': '', 'isoverseas': False, 'playingxichange': ''}, {'id': 11131, 'balls': 56, 'runs': 84, 'fours': 9, 'sixes': 3, 'strkrate': '150', 'name': 'Lorcan Tucker', 'nickname': '', 'iscaptain': False, 'iskeeper': False, 'outdec': 'b Netravalkar', 'vi
# ...

# %%
Scores=first_score['batsman']
print("id",Scores)
# Out:
# id [{'id': 1114, 'balls': 5, 'runs': 5, 'fours': 1, 'sixes': 0, 'strkrate': '100', 'name': 'Stirling', 'nickname': '', 'iscaptain': False, 'iskeeper': False, 'outdec': 'lbw b Nisarg Patel', 'videotype': '', 'videourl': '', 'videoid': 0, 'planid': 0, 'imageid': 0, 'premiumvideourl': '', 'iscbplusfree': False, 'ispremiumfree': False, 'inmatchchange': '', 'isoverseas': False, 'playingxichange': ''}, {'id': 6710, 'balls': 5, 'runs': 10, 'fours': 2, 'sixes': 0, 'strkrate': '200', 'name': 'Balbirnie', 'nickname': '', 'iscaptain': True, 'iskeeper': False, 'outdec': 'c Sushant Modani b Netravalkar', 'videotype': '', 'videourl': '', 'videoid': 0, 'planid': 0, 'imageid': 0, 'premiumvideourl': '', 'iscbplusfree': False, 'ispremiumfree': False, 'inmatchchange': '', 'isoverseas': False, 'playingxichange': ''}, {'id': 11131, 'balls': 56, 'runs': 84, 'fours': 9, 'sixes': 3, 'strkrate': '150', 'name': 'Lorcan Tucker', 'nickname': '', 'iscaptain': False, 'iskeeper': False, 'outdec': 'b Netravalkar', 
# ...

# %%
score_list = []


for innings in data.get("scorecard", []):
    for player in innings.get("batsman", []):
        score_list.append({
            "id": player.get("id"),
            "name": player.get("name"),
            "runs": player.get("runs"),
            "balls": player.get("balls"),
            "fours": player.get("fours"),
            "sixes": player.get("sixes"),
            "strikerate": player.get("strikerate"),
            "isCaptain": player.get("iscaptain"),
            "isKeeper": player.get("iskeeper"),
            "outDesc": player.get("outDec")
        })

print(score_list)
# Out:
# [{'id': 1114, 'name': 'Stirling', 'runs': 5, 'balls': 5, 'fours': 1, 'sixes': 0, 'strikerate': None, 'isCaptain': False, 'isKeeper': False, 'outDesc': None}, {'id': 6710, 'name': 'Balbirnie', 'runs': 10, 'balls': 5, 'fours': 2, 'sixes': 0, 'strikerate': None, 'isCaptain': True, 'isKeeper': False, 'outDesc': None}, {'id': 11131, 'name': 'Lorcan Tucker', 'runs': 84, 'balls': 56, 'fours': 9, 'sixes': 3, 'strikerate': None, 'isCaptain': False, 'isKeeper': False, 'outDesc': None}, {'id': 18143, 'name': 'Curtis Campher', 'runs': 17, 'balls': 11, 'fours': 2, 'sixes': 1, 'strikerate': None, 'isCaptain': False, 'isKeeper': False, 'outDesc': None}, {'id': 6471, 'name': 'Getkate', 'runs': 5, 'balls': 10, 'fours': 0, 'sixes': 0, 'strikerate': None, 'isCaptain': False, 'isKeeper': False, 'outDesc': None}, {'id': 13309, 'name': 'Neil Rock', 'runs': 4, 'balls': 5, 'fours': 0, 'sixes': 0, 'strikerate': None, 'isCaptain': False, 'isKeeper': True, 'outDesc': None}, {'id': 11129, 'name': 'William McCli
# ...

# %%
schedule

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/schedule/v1/international"

headers = {
	"x-rapidapi-key": "bf10e75c34mshe29d2ac7bca38cep143477jsn19fd2ab2770f",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'matchScheduleMap': [{'scheduleAdWrapper': {'date': 'TUE, OCT 28 2025', 'matchScheduleList': [{'seriesName': 'South Africa tour of Pakistan, 2025', 'matchInfo': [{'matchId': 134370, 'seriesId': 10895, 'matchDesc': '1st T20I', 'matchFormat': 'T20', 'startDate': '1761663600000', 'endDate': '1761695999000', 'team1': {'teamId': 3, 'teamName': 'Pakistan', 'teamSName': 'PAK', 'isFullMember': True, 'imageId': 776308}, 'team2': {'teamId': 11, 'teamName': 'South Africa', 'teamSName': 'RSA', 'isFullMember': True, 'imageId': 776287}, 'venueInfo': {'ground': 'Rawalpindi Cricket Stadium', 'city': 'Rawalpindi', 'country': 'Pakistan', 'timezone': '+05:00'}}], 'seriesId': 10895, 'seriesCategory': 'International'}], 'longDate': '1761609600000'}}, {'adDetail': {'name': 'native_news_index_random_1', 'layout': 'native_large', 'position': 1}}, {'scheduleAdWrapper': {'date': 'WED, OCT 29 2025', 'matchScheduleList': [{'seriesName': 'England tour of New Zealand, 2025', 'matchInfo': [{'matchId': 122577, 'se
# ...

# %%
data=(response.json())
print(data)
# Out:
# {'matchScheduleMap': [{'scheduleAdWrapper': {'date': 'TUE, OCT 28 2025', 'matchScheduleList': [{'seriesName': 'South Africa tour of Pakistan, 2025', 'matchInfo': [{'matchId': 134370, 'seriesId': 10895, 'matchDesc': '1st T20I', 'matchFormat': 'T20', 'startDate': '1761663600000', 'endDate': '1761695999000', 'team1': {'teamId': 3, 'teamName': 'Pakistan', 'teamSName': 'PAK', 'isFullMember': True, 'imageId': 776308}, 'team2': {'teamId': 11, 'teamName': 'South Africa', 'teamSName': 'RSA', 'isFullMember': True, 'imageId': 776287}, 'venueInfo': {'ground': 'Rawalpindi Cricket Stadium', 'city': 'Rawalpindi', 'country': 'Pakistan', 'timezone': '+05:00'}}], 'seriesId': 10895, 'seriesCategory': 'International'}], 'longDate': '1761609600000'}}, {'adDetail': {'name': 'native_news_index_random_1', 'layout': 'native_large', 'position': 1}}, {'scheduleAdWrapper': {'date': 'WED, OCT 29 2025', 'matchScheduleList': [{'seriesName': 'England tour of New Zealand, 2025', 'matchInfo': [{'matchId': 122577, 'se
# ...

# %%
data1=data.keys()
print(data1)
# Out:
# dict_keys(['matchScheduleMap', 'startDt', 'appIndex'])

# %%
data2=data['matchScheduleMap']
print(data2)
# Out:
# [{'scheduleAdWrapper': {'date': 'TUE, OCT 28 2025', 'matchScheduleList': [{'seriesName': 'South Africa tour of Pakistan, 2025', 'matchInfo': [{'matchId': 134370, 'seriesId': 10895, 'matchDesc': '1st T20I', 'matchFormat': 'T20', 'startDate': '1761663600000', 'endDate': '1761695999000', 'team1': {'teamId': 3, 'teamName': 'Pakistan', 'teamSName': 'PAK', 'isFullMember': True, 'imageId': 776308}, 'team2': {'teamId': 11, 'teamName': 'South Africa', 'teamSName': 'RSA', 'isFullMember': True, 'imageId': 776287}, 'venueInfo': {'ground': 'Rawalpindi Cricket Stadium', 'city': 'Rawalpindi', 'country': 'Pakistan', 'timezone': '+05:00'}}], 'seriesId': 10895, 'seriesCategory': 'International'}], 'longDate': '1761609600000'}}, {'adDetail': {'name': 'native_news_index_random_1', 'layout': 'native_large', 'position': 1}}, {'scheduleAdWrapper': {'date': 'WED, OCT 29 2025', 'matchScheduleList': [{'seriesName': 'England tour of New Zealand, 2025', 'matchInfo': [{'matchId': 122577, 'seriesId': 10212, 'matc
# ...

# %%
data3=data2[0].keys()
print(data3)
# Out:
# dict_keys(['scheduleAdWrapper'])

# %%
data4=data
print(data4.keys())
# Out:
# dict_keys(['matchScheduleMap', 'startDt', 'appIndex'])

# %%
data4=data['matchScheduleMap']
first_list=data4[0]
print(first_list['scheduleAdWrapper'])
# Out:
# {'date': 'TUE, OCT 28 2025', 'matchScheduleList': [{'seriesName': 'South Africa tour of Pakistan, 2025', 'matchInfo': [{'matchId': 134370, 'seriesId': 10895, 'matchDesc': '1st T20I', 'matchFormat': 'T20', 'startDate': '1761663600000', 'endDate': '1761695999000', 'team1': {'teamId': 3, 'teamName': 'Pakistan', 'teamSName': 'PAK', 'isFullMember': True, 'imageId': 776308}, 'team2': {'teamId': 11, 'teamName': 'South Africa', 'teamSName': 'RSA', 'isFullMember': True, 'imageId': 776287}, 'venueInfo': {'ground': 'Rawalpindi Cricket Stadium', 'city': 'Rawalpindi', 'country': 'Pakistan', 'timezone': '+05:00'}}], 'seriesId': 10895, 'seriesCategory': 'International'}], 'longDate': '1761609600000'}
